# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLO model
model = YOLO("../models/yantra_model_1.pt")

# Load video file
cap = cv2.VideoCapture("../test_videos/static_prob_1_org.mp4")

# Initialize counters
left_counter = 0
right_counter = 0
straight_counter = 0

# Track previous positions
previous_centers = {}
counted_objects = {'left': set(), 'right': set(), 'straight': set()}

# Define crossing lines (Adjust based on your video)
left_line = ((218, 1584), (451, 940))      # Example: Line for left turn
right_line = ((2093, 1510), (1604, 844))    # Example: Line for right turn
straight_line = ((2093, 1510), (218, 1584))  # Example: Line for straight movement



def is_crossing(p1, p2, line):
    """Check if a car's center crosses a given line"""
    x1, y1 = line[0]
    x2, y2 = line[1]

    if (p1[1] > y1 and p2[1] < y2) or (p1[1] < y1 and p2[1] > y2):
        return True
    return False

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO model
    results = model(frame)

    # Store current frame positions
    current_centers = {}

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls = int(box.cls[0])

            # Assume all detections are cars (Modify if needed)
            car_id = f"{x1}_{y1}_{x2}_{y2}"  # Generate a unique ID based on box
            center = ((x1 + x2) // 2, (y1 + y2) // 2)
            current_centers[car_id] = center

            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Draw center point
            cv2.circle(frame, center, 5, (255, 0, 0), -1)

            # Check movement direction
            if car_id in previous_centers:
                prev_center = previous_centers[car_id]

                if is_crossing(prev_center, center, left_line) and car_id not in counted_objects['left']:
                    left_counter += 1
                    counted_objects['left'].add(car_id)

                elif is_crossing(prev_center, center, right_line) and car_id not in counted_objects['right']:
                    right_counter += 1
                    counted_objects['right'].add(car_id)

                elif is_crossing(prev_center, center, straight_line) and car_id not in counted_objects['straight']:
                    straight_counter += 1
                    counted_objects['straight'].add(car_id)

    # Update previous positions
    previous_centers = current_centers

    # Draw Lines
    cv2.line(frame, left_line[0], left_line[1], (255, 0, 0), 3)
    cv2.line(frame, right_line[0], right_line[1], (0, 255, 0), 3)
    cv2.line(frame, straight_line[0], straight_line[1], (0, 0, 255), 3)

    # Display Counters
    cv2.putText(frame, f"Left: {left_counter}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Right: {right_counter}", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Straight: {straight_counter}", (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Show frame
    cv2.imshow("Car Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 cars, 45.7ms
# Speed: 2.2ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 57.0ms
# Speed: 1.6ms preprocess, 57.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 55.0ms
# Speed: 1.7ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# 2025-02-08 11:59:23.964 python[89755:2544120] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-08 11:59:23.964 python[89755:2544120] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 480x640 4 cars, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 58.8ms
# Speed: 2.1ms preprocess, 58.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.9ms
# Speed: 1.8ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.4ms
# Speed: 1.8ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.4ms
# Speed: 1.6ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.6ms
# Speed: 1.6ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.2ms
# Speed: 1.9ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.6ms
# Speed: 1.8ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.6ms
# Speed: 1.7ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.3ms
# Speed: 1.8ms preprocess, 46.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.9ms
# Speed: 1.8ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.5ms
# Speed: 1.7ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.6ms
# Speed: 1.7ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 53.3ms
# Speed: 1.9ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 52.0ms
# Speed: 1.8ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 54.4ms
# Speed: 1.6ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.9ms
# Speed: 1.7ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.7ms
# Speed: 2.5ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.9ms
# Speed: 1.7ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.7ms
# Speed: 1.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 50.5ms
# Speed: 1.9ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 52.7ms
# Speed: 1.7ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.3ms
# Speed: 1.7ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.8ms
# Speed: 1.8ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.7ms
# Speed: 1.6ms preprocess, 46.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.8ms
# Speed: 1.7ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.4ms
# Speed: 1.6ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.5ms
# Speed: 1.7ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 58.2ms
# Speed: 1.6ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.3ms
# Speed: 1.7ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.8ms
# Speed: 1.5ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.0ms
# Speed: 1.6ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.3ms
# Speed: 1.8ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.1ms
# Speed: 1.6ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 55.9ms
# Speed: 1.7ms preprocess, 55.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.6ms
# Speed: 1.8ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.6ms
# Speed: 1.6ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.0ms
# Speed: 2.6ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.2ms
# Speed: 2.1ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 5.3ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.7ms
# Speed: 1.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.4ms
# Speed: 1.6ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.5ms
# Speed: 1.7ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 38.2ms
# Speed: 1.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 48.6ms
# Speed: 1.6ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 55.6ms
# Speed: 1.9ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 58.9ms
# Speed: 1.6ms preprocess, 58.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.7ms
# Speed: 1.6ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.8ms
# Speed: 1.7ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.0ms
# Speed: 1.9ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.4ms
# Speed: 1.9ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.8ms
# Speed: 1.5ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.2ms
# Speed: 2.3ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.6ms
# Speed: 1.8ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.7ms
# Speed: 1.6ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.9ms
# Speed: 1.8ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 37.1ms
# Speed: 1.6ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.2ms
# Speed: 1.6ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.7ms
# Speed: 1.7ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.3ms
# Speed: 1.8ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.8ms
# Speed: 1.7ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.3ms
# Speed: 1.9ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.6ms
# Speed: 1.9ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.4ms
# Speed: 1.8ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 58.3ms
# Speed: 1.8ms preprocess, 58.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.0ms
# Speed: 1.9ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.4ms
# Speed: 2.2ms preprocess, 73.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.3ms
# Speed: 1.8ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.5ms
# Speed: 1.6ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.0ms
# Speed: 1.6ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.1ms
# Speed: 1.6ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.6ms
# Speed: 1.6ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.4ms
# Speed: 2.3ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.3ms
# Speed: 2.0ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.7ms
# Speed: 1.8ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 55.4ms
# Speed: 1.6ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 46.3ms
# Speed: 1.9ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 49.0ms
# Speed: 1.7ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.0ms
# Speed: 1.9ms preprocess, 45.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 55.3ms
# Speed: 1.6ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 43.5ms
# Speed: 4.8ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 48.8ms
# Speed: 1.8ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 40.7ms
# Speed: 1.7ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 57.7ms
# Speed: 1.6ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 55.0ms
# Speed: 1.9ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 46.3ms
# Speed: 1.7ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 1.7ms preprocess, 58.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.8ms
# Speed: 1.7ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 4.4ms preprocess, 43.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 1.9ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.4ms
# Speed: 1.8ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 2.2ms preprocess, 43.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.8ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.3ms
# Speed: 1.6ms preprocess, 49.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.4ms
# Speed: 1.7ms preprocess, 60.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.5ms
# Speed: 1.8ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.5ms
# Speed: 1.9ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 1.8ms preprocess, 51.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# ...
# Speed: 1.9ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.1ms
# Speed: 1.9ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.9ms
# Speed: 1.8ms preprocess, 47.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.9ms
# Speed: 1.9ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.5ms
# Speed: 1.8ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 61.7ms
# Speed: 1.6ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.3ms
# Speed: 1.9ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.9ms
# Speed: 1.7ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.5ms
# Speed: 1.9ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.6ms
# Speed: 1.6ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.4ms
# Speed: 1.8ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.1ms
# Speed: 1.8ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.4ms
# Speed: 1.8ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.8ms
# Speed: 1.8ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 57.3ms
# Speed: 2.1ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.9ms
# Speed: 1.9ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.3ms
# Speed: 1.6ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.8ms
# Speed: 1.8ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.3ms
# Speed: 2.0ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.0ms
# Speed: 1.6ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.3ms
# Speed: 1.7ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.4ms
# Speed: 1.8ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.6ms
# Speed: 1.6ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.3ms
# Speed: 1.7ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.8ms
# Speed: 2.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.9ms
# Speed: 1.6ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.7ms
# Speed: 2.0ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.6ms
# Speed: 1.7ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.0ms
# Speed: 1.7ms preprocess, 52.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.1ms
# Speed: 2.0ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.7ms
# Speed: 1.7ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.2ms
# Speed: 1.7ms preprocess, 59.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.9ms
# Speed: 1.9ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.0ms
# Speed: 1.8ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.0ms
# Speed: 1.7ms preprocess, 63.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 94.2ms
# Speed: 1.8ms preprocess, 94.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.3ms
# Speed: 1.8ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.2ms
# Speed: 1.8ms preprocess, 80.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.0ms
# Speed: 1.9ms preprocess, 71.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.4ms
# Speed: 1.8ms preprocess, 82.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.6ms
# Speed: 1.7ms preprocess, 54.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.7ms
# Speed: 1.8ms preprocess, 81.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.9ms
# Speed: 1.8ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.6ms
# Speed: 1.8ms preprocess, 86.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.4ms
# Speed: 1.9ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.3ms
# Speed: 1.7ms preprocess, 74.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.1ms
# Speed: 1.8ms preprocess, 74.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.6ms
# Speed: 1.9ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.5ms
# Speed: 1.7ms preprocess, 74.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.1ms
# Speed: 1.7ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.2ms
# Speed: 1.8ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 72.5ms
# Speed: 1.8ms preprocess, 72.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.0ms
# Speed: 1.9ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.2ms
# Speed: 1.9ms preprocess, 73.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.7ms
# Speed: 1.6ms preprocess, 77.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.7ms
# Speed: 1.8ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.8ms
# Speed: 1.9ms preprocess, 74.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.5ms
# Speed: 1.9ms preprocess, 77.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 1.9ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.3ms
# Speed: 1.9ms preprocess, 55.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.2ms
# Speed: 1.8ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.7ms
# Speed: 1.7ms preprocess, 46.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.6ms

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("../models/yantra_model_1.pt")
# Load video file
url = "../test_videos/static_prob_1_org.mp4"
cap = cv2.VideoCapture(url)

# Initialize counters and tracking
left_counter = 0
right_counter = 0
straight_counter = 0
previous_centers = {}
counted_objects = {'left': set(), 'right': set(), 'straight': set()}

def check_left_crossing(p1, p2):
    """Detect if an object moves from right to left across the 1604 x-line."""
    # Changed condition: now checks if object moves from right (>1604) to left (<1604)
    return p1[1] <= 415

def check_right_crossing(p1, p2):
    """Detect if an object moves from left to right across the 218 x-line."""
    # Changed condition: now checks if object moves from left (>218) to right (<218)
    return p1[1] >=1604

def check_straight_crossing(p1, p2):
    """Detect if an object moves from bottom to top across the 1510 y-line."""
    # Changed condition: now checks if object moves from bottom (>1510) to top (<1510)
    return p1[0] >= 1510

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Get YOLO detections
    results = model(frame)
    current_centers = {}
    
    # Process each detection
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])
            
            # Calculate center point
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            
            # Create unique object ID
            object_id = f"{cls}_{x1}_{y1}_{x2}_{y2}"
            current_centers[object_id] = (center_x, center_y)
            
            # Draw bounding box and label
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"{model.names[cls]} {conf:.2f}"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            
            # Draw center point
            cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)
            
            # Check for line crossings if we have a previous position
            if object_id in previous_centers:
                prev_center = previous_centers[object_id]
                curr_center = (center_x, center_y)
                
                # Debug visualization of tracked movement
                cv2.line(frame, prev_center, curr_center, (255, 0, 0), 2)
                
                # Check left crossing (right to left)
                if (object_id not in counted_objects['left'] and 
                    check_left_crossing(prev_center, curr_center)):
                    left_counter += 1
                    counted_objects['left'].add(object_id)
                    # Debug print
                    print(f"Left crossing detected: {prev_center} -> {curr_center}")
                
                # Check right crossing (left to right)
                if (object_id not in counted_objects['right'] and 
                    check_right_crossing(prev_center, curr_center)):
                    right_counter += 1
                    counted_objects['right'].add(object_id)
                    # Debug print
                    print(f"Right crossing detected: {prev_center} -> {curr_center}")
                
                # Check straight crossing (bottom to top)
                if (object_id not in counted_objects['straight'] and 
                    check_straight_crossing(prev_center, curr_center)):
                    straight_counter += 1
                    counted_objects['straight'].add(object_id)
                    # Debug print
                    print(f"Straight crossing detected: {prev_center} -> {curr_center}")

    # Draw boundary lines
    cv2.line(frame, (218, 1584), (451, 940), (0, 255, 0), 3)  # Left boundary
    cv2.line(frame, (2093, 1510), (1604, 844), (0, 255, 0), 3)  # Right boundary
    cv2.line(frame, (2093, 1510), (218, 1584), (0, 255, 0), 3)  # Straight line
    
    # Draw counters
    cv2.putText(frame, f"Left: {left_counter}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Right: {right_counter}", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Straight: {straight_counter}", (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Update previous centers
    previous_centers = current_centers.copy()
    
    # Show frame
    cv2.imshow("ESP32-CAM", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 cars, 47.4ms
# Speed: 2.9ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 58.0ms
# Speed: 2.6ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 59.0ms
# Speed: 2.8ms preprocess, 59.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 51.6ms
# Speed: 2.4ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 51.4ms
# Speed: 2.3ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 51.7ms
# Speed: 2.6ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.1ms
# Speed: 2.4ms preprocess, 48.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# 2025-02-08 04:56:18.168 python[85719:2456216] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-08 04:56:18.168 python[85719:2456216] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 480x640 4 cars, 47.4ms
# Speed: 2.4ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.9ms
# Speed: 2.5ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 53.1ms
# Speed: 2.5ms preprocess, 53.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 59.8ms
# Speed: 2.6ms preprocess, 59.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.0ms
# Speed: 2.5ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 51.0ms
# Speed: 2.3ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.6ms
# Speed: 2.3ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.5ms
# Speed: 2.3ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.4ms
# Speed: 2.3ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.4ms
# Speed: 2.3ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.1ms
# Speed: 2.3ms preprocess, 45.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.7ms
# Speed: 2.2ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.7ms
# Speed: 2.3ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.2ms
# Speed: 2.4ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.9ms
# Speed: 2.2ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.4ms
# Speed: 2.2ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.0ms
# Speed: 2.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.3ms
# Speed: 4.2ms preprocess, 64.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.2ms
# Speed: 2.5ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.4ms
# Speed: 2.5ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 53.7ms
# Speed: 3.3ms preprocess, 53.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 63.9ms
# Speed: 3.6ms preprocess, 63.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.0ms
# Speed: 3.6ms preprocess, 76.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.5ms
# Speed: 3.6ms preprocess, 76.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 80.8ms
# Speed: 3.5ms preprocess, 80.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.5ms
# Speed: 3.5ms preprocess, 77.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 88.6ms
# Speed: 3.7ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 78.9ms
# Speed: 3.6ms preprocess, 78.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.2ms
# Speed: 3.6ms preprocess, 86.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 75.6ms
# Speed: 3.7ms preprocess, 75.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 83.5ms
# Speed: 3.6ms preprocess, 83.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 105.9ms
# Speed: 4.0ms preprocess, 105.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 93.5ms
# Speed: 3.7ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 68.5ms
# Speed: 3.7ms preprocess, 68.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.1ms
# Speed: 4.0ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 78.0ms
# Speed: 3.8ms preprocess, 78.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 85.6ms
# Speed: 3.7ms preprocess, 85.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1540, 1192) -> (1540, 1192)
#
# 0: 480x640 3 cars, 70.4ms
# Speed: 3.7ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.1ms
# Speed: 3.5ms preprocess, 87.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 69.5ms
# Speed: 3.8ms preprocess, 69.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.2ms
# Speed: 3.7ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 91.0ms
# Speed: 3.7ms preprocess, 91.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 73.5ms
# Speed: 3.5ms preprocess, 73.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1540, 1192) -> (1540, 1192)
#
# 0: 480x640 3 cars, 84.8ms
# Speed: 3.6ms preprocess, 84.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.2ms
# Speed: 3.5ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 101.9ms
# Speed: 3.6ms preprocess, 101.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 81.8ms
# Speed: 3.6ms preprocess, 81.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1540, 1193) -> (1540, 1193)
#
# 0: 480x640 3 cars, 80.4ms
# Speed: 3.7ms preprocess, 80.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 110.8ms
# Speed: 3.9ms preprocess, 110.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.4ms
# Speed: 3.5ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.0ms
# Speed: 3.7ms preprocess, 86.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 72.4ms
# Speed: 3.5ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.5ms
# Speed: 3.8ms preprocess, 76.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 81.3ms
# Speed: 3.5ms preprocess, 81.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 109.7ms
# Speed: 4.4ms preprocess, 109.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1540, 1192) -> (1540, 1192)
#
# 0: 480x640 3 cars, 100.4ms
# Speed: 3.7ms preprocess, 100.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 95.1ms
# Speed: 4.1ms preprocess, 95.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.4ms
# Speed: 3.9ms preprocess, 86.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.7ms
# Speed: 3.8ms preprocess, 76.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1540, 1193) -> (1540, 1193)
#
# 0: 480x640 3 cars, 100.7ms
# Speed: 4.9ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.6ms
# Speed: 3.9ms preprocess, 87.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 120.0ms
# Speed: 4.5ms preprocess, 120.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 97.1ms
# Speed: 3.9ms preprocess, 97.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 95.1ms
# Speed: 4.1ms preprocess, 95.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.3ms
# Speed: 3.5ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.1ms
# Speed: 3.7ms preprocess, 77.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 65.9ms
# Speed: 3.5ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 68.6ms
# Speed: 3.7ms preprocess, 68.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1561, 1234) -> (1561, 1234)
#
# 0: 480x640 3 cars, 62.8ms
# Speed: 3.7ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 73.3ms
# Speed: 3.7ms preprocess, 73.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 60.2ms
# Speed: 3.6ms preprocess, 60.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.7ms
# Speed: 3.4ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 78.9ms
# Speed: 4.0ms preprocess, 78.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.9ms
# Speed: 3.6ms preprocess, 64.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 70.4ms
# Speed: 3.9ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1641, 1312) -> (1641, 1312)
#
# 0: 480x640 4 cars, 58.3ms
# Speed: 3.4ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 68.0ms
# Speed: 3.5ms preprocess, 68.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.5ms
# Speed: 4.0ms preprocess, 64.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.9ms
# Speed: 3.4ms preprocess, 64.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 69.4ms
# Speed: 3.6ms preprocess, 69.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.2ms
# Speed: 3.7ms preprocess, 64.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 71.7ms
# Speed: 3.6ms preprocess, 71.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 78.7ms
# Speed: 3.8ms preprocess, 78.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 69.5ms
# Speed: 9.6ms preprocess, 69.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 63.4ms
# Speed: 3.6ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 70.2ms
# Speed: 3.8ms preprocess, 70.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.1ms
# Speed: 3.4ms preprocess, 64.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1641, 1314) -> (1641, 1314)
#
# 0: 480x640 4 cars, 65.1ms
# Speed: 4.1ms preprocess, 65.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 65.6ms
# Speed: 4.0ms preprocess, 65.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.3ms
# Speed: 3.6ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 67.0ms
# Speed: 3.5ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 72.5ms
# Speed: 3.8ms preprocess, 72.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 104.9ms
# Speed: 3.8ms preprocess, 104.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1640, 1313) -> (1640, 1313)
#
# 0: 480x640 4 cars, 58.6ms
# Speed: 4.1ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 70.4ms
# Speed: 3.8ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 62.8ms
# Speed: 4.0ms preprocess, 62.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 63.6ms
# Speed: 4.0ms preprocess, 63.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 69.4ms
# Speed: 3.5ms preprocess, 69.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1640, 1312) -> (1640, 1312)
#
# 0: 480x640 4 cars, 63.4ms
# Speed: 3.7ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 76.3ms
# Speed: 3.6ms preprocess, 76.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 74.9ms
# Speed: 3.8ms preprocess, 74.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 72.0ms
# Speed: 3.7ms preprocess, 72.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 63.6ms
# Speed: 3.6ms preprocess, 63.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 74.9ms
# Speed: 3.7ms preprocess, 74.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 64.7ms
# Speed: 3.8ms preprocess, 64.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 66.6ms
# Speed: 3.6ms preprocess, 66.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 70.0ms
# Speed: 3.6ms preprocess, 70.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 68.9ms
# Speed: 3.6ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 95.2ms
# Speed: 3.7ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 76.2ms
# Speed: 3.9ms preprocess, 76.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Straight crossing detected: (1785, 1441) -> (1785, 1441)
#
# 0: 480x640 4 cars, 78.9ms
# Speed: 3.6ms preprocess, 78.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 71.0ms
# Speed: 4.0ms preprocess, 71.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 84.1ms
# Speed: 3.6ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 74.9ms
# Speed: 3.6ms preprocess, 74.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 108.0ms
# Speed: 3.6ms preprocess, 108.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.3ms
# Speed: 3.8ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.6ms
# Speed: 4.0ms preprocess, 87.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 80.2ms
# Speed: 4.2ms preprocess, 80.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 75.7ms
# Speed: 3.6ms preprocess, 75.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 80.1ms
# Speed: 3.8ms preprocess, 80.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 84.9ms
# Speed: 3.7ms preprocess, 84.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.3ms
# Speed: 3.5ms preprocess, 74.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 109.5ms
# Speed: 4.0ms preprocess, 109.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 90.9ms
# Speed: 3.7ms preprocess, 90.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 84.2ms
# Speed: 3.5ms preprocess, 84.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.7ms
# Speed: 3.8ms preprocess, 77.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 89.8ms
# Speed: 3.5ms preprocess, 89.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.2ms
# Speed: 3.9ms preprocess, 76.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 108.9ms
# Speed: 3.8ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 75.1ms
# Speed: 3.6ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 93.7ms
# Speed: 3.8ms preprocess, 93.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.5ms
# Speed: 3.6ms preprocess, 79.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 85.6ms
# Speed: 3.7ms preprocess, 85.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 86.4ms
# Speed: 3.8ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 105.9ms
# Speed: 3.6ms preprocess, 105.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.2ms
# Speed: 4.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 85.6ms
# Speed: 3.6ms preprocess, 85.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 69.5ms
# Speed: 3.9ms preprocess, 69.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.3ms
# Speed: 3.7ms preprocess, 79.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.5ms
# Speed: 3.6ms preprocess, 76.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 96.8ms
# Speed: 3.8ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 87.4ms
# Speed: 4.9ms preprocess, 87.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.6ms
# Speed: 3.8ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 88.3ms
# Speed: 3.8ms preprocess, 88.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 78.4ms
# Speed: 3.4ms preprocess, 78.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 92.7ms
# Speed: 3.6ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 105.3ms
# Speed: 3.7ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.7ms
# Speed: 3.9ms preprocess, 67.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.0ms
# Speed: 3.6ms preprocess, 79.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.1ms
# Speed: 3.8ms preprocess, 77.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.6ms
# Speed: 4.0ms preprocess, 67.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 101.2ms
# Speed: 3.8ms preprocess, 101.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 77.3ms
# Speed: 9.4ms preprocess, 77.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 80.4ms
# Speed: 3.6ms preprocess, 80.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 63.5ms
# Speed: 3.6ms preprocess, 63.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.7ms
# Speed: 3.7ms preprocess, 74.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 59.2ms
# Speed: 3.9ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.0ms
# Speed: 3.7ms preprocess, 76.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 81.4ms
# Speed: 3.8ms preprocess, 81.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.6ms
# Speed: 3.6ms preprocess, 67.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 62.0ms
# Speed: 3.5ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 68.9ms
# Speed: 3.6ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 59.4ms
# Speed: 3.4ms preprocess, 59.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.4ms
# Speed: 3.8ms preprocess, 79.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 68.8ms
# Speed: 4.5ms preprocess, 68.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.0ms
# Speed: 3.6ms preprocess, 67.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 69.3ms
# Speed: 3.9ms preprocess, 69.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 95.2ms
# Speed: 3.6ms preprocess, 95.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 71.5ms
# Speed: 13.8ms preprocess, 71.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 100.7ms
# Speed: 3.6ms preprocess, 100.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 108.1ms
# Speed: 4.0ms preprocess, 108.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 101.5ms
# Speed: 4.3ms preprocess, 101.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 90.5ms
# Speed: 3.9ms preprocess, 90.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 109.7ms
# Speed: 4.1ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 114.0ms
# Speed: 4.2ms preprocess, 114.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 93.2ms
# Speed: 4.0ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 91.7ms
# Speed: 3.9ms preprocess, 91.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 72.0ms
# Speed: 3.8ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 99.4ms
# Speed: 4.0ms preprocess, 99.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 76.4ms
# Speed: 11.3ms preprocess, 76.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 78.3ms
# Speed: 3.8ms preprocess, 78.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.7ms
# Speed: 3.7ms preprocess, 79.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 71.7ms
# Speed: 3.9ms preprocess, 71.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 117.2ms
# Speed: 3.7ms preprocess, 117.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 82.6ms
# Speed: 3.6ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 88.6ms
# Speed: 3.8ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 81.7ms
# Speed: 3.6ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 73.8ms
# Speed: 4.0ms preprocess, 73.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 99.9ms
# Speed: 3.7ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 72.1ms
# Speed: 3.7ms preprocess, 72.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 82.8ms
# Speed: 3.6ms preprocess, 82.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 64.7ms
# Speed: 4.2ms preprocess, 64.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 80.5ms
# Speed: 4.0ms preprocess, 80.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.2ms
# Speed: 5.2ms preprocess, 74.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 64.1ms
# Speed: 3.5ms preprocess, 64.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 74.5ms
# Speed: 3.6ms preprocess, 74.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 60.3ms
# Speed: 3.6ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 79.2ms
# Speed: 3.9ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 65.4ms
# Speed: 3.7ms preprocess, 65.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 77.5ms
# Speed: 3.8ms preprocess, 77.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 77.7ms
# Speed: 3.7ms preprocess, 77.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 92.2ms
# Speed: 4.0ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 87.5ms
# Speed: 4.2ms preprocess, 87.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 73.9ms
# Speed: 3.6ms preprocess, 73.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 76.7ms
# Speed: 3.6ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 72.8ms
# Speed: 3.5ms preprocess, 72.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 106.3ms
# Speed: 4.1ms preprocess, 106.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 72.6ms
# Speed: 3.8ms preprocess, 72.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 80.8ms
# Speed: 3.5ms preprocess, 80.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 70.8ms
# Speed: 3.5ms preprocess, 70.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 101.7ms
# Speed: 4.3ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 72.3ms
# Speed: 3.5ms preprocess, 72.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.3ms
# Speed: 3.6ms preprocess, 81.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.4ms
# Speed: 3.6ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 88.4ms
# Speed: 4.2ms preprocess, 88.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.4ms
# Speed: 7.6ms preprocess, 65.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.0ms
# Speed: 3.8ms preprocess, 76.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.8ms
# Speed: 3.6ms preprocess, 64.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.8ms
# Speed: 3.7ms preprocess, 81.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 107.8ms
# Speed: 3.8ms preprocess, 107.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.6ms
# Speed: 3.7ms preprocess, 74.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.8ms
# Speed: 3.6ms preprocess, 82.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 96.5ms
# Speed: 4.1ms preprocess, 96.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 100.4ms
# Speed: 3.8ms preprocess, 100.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.8ms
# Speed: 3.9ms preprocess, 82.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 79.0ms
# Speed: 3.6ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 94.6ms
# Speed: 3.8ms preprocess, 94.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.7ms
# Speed: 7.0ms preprocess, 74.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 87.0ms
# Speed: 3.7ms preprocess, 87.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.8ms
# Speed: 3.9ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 99.3ms
# Speed: 3.6ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.7ms
# Speed: 3.4ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.0ms
# Speed: 3.7ms preprocess, 83.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.7ms
# Speed: 3.9ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 102.7ms
# Speed: 4.2ms preprocess, 102.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.8ms
# Speed: 4.0ms preprocess, 77.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.6ms
# Speed: 3.7ms preprocess, 76.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.8ms
# Speed: 3.7ms preprocess, 73.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 107.0ms
# Speed: 3.8ms preprocess, 107.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.2ms
# Speed: 3.4ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 98.8ms
# Speed: 3.8ms preprocess, 98.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.9ms
# Speed: 3.7ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 85.4ms
# Speed: 4.2ms preprocess, 85.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.5ms
# Speed: 3.5ms preprocess, 82.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.5ms
# Speed: 3.9ms preprocess, 82.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.6ms
# Speed: 3.7ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 107.0ms
# Speed: 4.1ms preprocess, 107.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.8ms
# Speed: 3.5ms preprocess, 71.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.7ms
# Speed: 3.6ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 103.1ms
# Speed: 3.7ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.1ms
# Speed: 3.9ms preprocess, 81.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 79.8ms
# Speed: 3.9ms preprocess, 79.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.1ms
# Speed: 3.6ms preprocess, 68.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.2ms
# Speed: 4.0ms preprocess, 80.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.3ms
# Speed: 3.8ms preprocess, 86.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.4ms
# Speed: 3.5ms preprocess, 76.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.2ms
# Speed: 4.3ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 115.4ms
# Speed: 3.8ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.1ms
# Speed: 3.8ms preprocess, 76.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.5ms
# Speed: 3.5ms preprocess, 76.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 94.9ms
# Speed: 4.0ms preprocess, 94.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 79.0ms
# Speed: 3.7ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.5ms
# Speed: 3.8ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.9ms
# Speed: 3.8ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.9ms
# Speed: 3.7ms preprocess, 73.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.7ms
# Speed: 3.8ms preprocess, 84.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.3ms
# Speed: 3.6ms preprocess, 66.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.6ms
# Speed: 3.8ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.6ms
# Speed: 3.5ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 114.9ms
# Speed: 3.8ms preprocess, 114.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 61.9ms
# Speed: 3.5ms preprocess, 61.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 85.9ms
# Speed: 3.5ms preprocess, 85.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.4ms
# Speed: 4.1ms preprocess, 82.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.4ms
# Speed: 4.3ms preprocess, 81.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 72.6ms
# Speed: 3.7ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.4ms
# Speed: 3.7ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 78.6ms
# Speed: 3.8ms preprocess, 78.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.3ms
# Speed: 4.6ms preprocess, 80.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.1ms
# Speed: 3.5ms preprocess, 65.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.7ms
# Speed: 4.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 97.9ms
# Speed: 3.9ms preprocess, 97.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 102.3ms
# Speed: 4.0ms preprocess, 102.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.2ms
# Speed: 4.2ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 85.6ms
# Speed: 3.8ms preprocess, 85.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 107.2ms
# Speed: 6.7ms preprocess, 107.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 103.6ms
# Speed: 4.5ms preprocess, 103.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 103.8ms
# Speed: 3.9ms preprocess, 103.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 91.0ms
# Speed: 4.0ms preprocess, 91.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 134.1ms
# Speed: 4.1ms preprocess, 134.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.8ms
# Speed: 4.4ms preprocess, 80.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.2ms
# Speed: 4.1ms preprocess, 83.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 100.4ms
# Speed: 4.3ms preprocess, 100.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 72.3ms
# Speed: 16.1ms preprocess, 72.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.7ms
# Speed: 3.5ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.4ms
# Speed: 3.7ms preprocess, 76.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.1ms
# Speed: 4.1ms preprocess, 81.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.0ms
# Speed: 3.9ms preprocess, 70.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.7ms
# Speed: 3.4ms preprocess, 66.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.0ms
# Speed: 3.7ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.6ms
# Speed: 3.7ms preprocess, 84.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.0ms
# Speed: 3.7ms preprocess, 68.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.6ms
# Speed: 3.8ms preprocess, 63.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.6ms
# Speed: 3.7ms preprocess, 77.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.7ms
# Speed: 4.2ms preprocess, 86.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.6ms
# Speed: 3.9ms preprocess, 71.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 72.1ms
# Speed: 3.7ms preprocess, 72.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 136.9ms
# Speed: 4.0ms preprocess, 136.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 81.4ms
# Speed: 3.8ms preprocess, 81.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 85.2ms
# Speed: 3.8ms preprocess, 85.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 99.0ms
# Speed: 3.9ms preprocess, 99.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 96.4ms
# Speed: 4.0ms preprocess, 96.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 79.5ms
# Speed: 3.5ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 76.3ms
# Speed: 3.9ms preprocess, 76.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 134.7ms
# Speed: 6.3ms preprocess, 134.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 78.5ms
# Speed: 3.8ms preprocess, 78.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 91.9ms
# Speed: 3.8ms preprocess, 91.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 118.3ms
# Speed: 3.6ms preprocess, 118.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 72.8ms
# Speed: 3.9ms preprocess, 72.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 94.2ms
# Speed: 3.9ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 96.3ms
# Speed: 4.4ms preprocess, 96.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 91.7ms
# Speed: 3.9ms preprocess, 91.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 78.1ms
# Speed: 3.7ms preprocess, 78.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 101.0ms
# Speed: 3.7ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 83.4ms
# Speed: 3.9ms preprocess, 83.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 77.3ms
# Speed: 3.7ms preprocess, 77.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 92.1ms
# Speed: 3.6ms preprocess, 92.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 92.6ms
# Speed: 5.4ms preprocess, 92.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 80.1ms
# Speed: 3.6ms preprocess, 80.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 78.0ms
# Speed: 3.6ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 110.0ms
# Speed: 3.9ms preprocess, 110.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 78.2ms
# Speed: 9.5ms preprocess, 78.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 78.7ms
# Speed: 3.9ms preprocess, 78.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 99.9ms
# Speed: 3.5ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 92.8ms
# Speed: 4.1ms preprocess, 92.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 77.5ms
# Speed: 3.5ms preprocess, 77.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 86.6ms
# Speed: 3.7ms preprocess, 86.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 100.5ms
# Speed: 3.7ms preprocess, 100.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 73.4ms
# Speed: 3.7ms preprocess, 73.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 104.1ms
# Speed: 3.7ms preprocess, 104.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 90.3ms
# Speed: 3.9ms preprocess, 90.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 93.2ms
# Speed: 3.6ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 79.2ms
# Speed: 3.5ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 110.1ms
# Speed: 3.9ms preprocess, 110.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 82.2ms
# Speed: 4.9ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 82.3ms
# Speed: 3.6ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 97.9ms
# Speed: 3.9ms preprocess, 97.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 vip, 88.7ms
# Speed: 4.1ms preprocess, 88.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.5ms
# Speed: 3.5ms preprocess, 91.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.9ms
# Speed: 3.7ms preprocess, 100.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.7ms
# Speed: 3.9ms preprocess, 99.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.4ms
# Speed: 3.5ms preprocess, 84.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.1ms
# Speed: 3.5ms preprocess, 82.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.1ms
# Speed: 3.9ms preprocess, 106.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.5ms
# Speed: 3.9ms preprocess, 72.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 71.2ms
# Speed: 3.7ms preprocess, 71.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.4ms
# Speed: 4.1ms preprocess, 77.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 4.1ms preprocess, 85.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.0ms
# Speed: 3.6ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.3ms
# Speed: 3.4ms preprocess, 68.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 4.0ms preprocess, 90.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 3.5ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.6ms
# Speed: 3.7ms preprocess, 73.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.3ms
# Speed: 3.9ms preprocess, 78.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.6ms
# Speed: 4.0ms preprocess, 87.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.9ms
# Speed: 3.7ms preprocess, 85.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 3.6ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.9ms
# Speed: 3.9ms preprocess, 98.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.1ms
# Speed: 4.3ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.2ms
# Speed: 3.8ms preprocess, 86.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.7ms
# Speed: 3.6ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.8ms
# Speed: 3.8ms preprocess, 102.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.7ms
# Speed: 4.0ms preprocess, 86.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.4ms
# Speed: 3.7ms preprocess, 82.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.9ms
# Speed: 4.0ms preprocess, 72.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.2ms
# Speed: 4.2ms preprocess, 99.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.2ms
# Speed: 4.8ms preprocess, 100.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.8ms
# Speed: 3.7ms preprocess, 77.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.9ms
# Speed: 3.6ms preprocess, 106.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 4.3ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 71.7ms
# Speed: 3.7ms preprocess, 71.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.4ms
# Speed: 4.0ms preprocess, 104.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.8ms
# Speed: 3.9ms preprocess, 95.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.0ms
# Speed: 3.6ms preprocess, 81.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.6ms
# Speed: 4.3ms preprocess, 98.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.8ms
# Speed: 3.8ms preprocess, 97.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.7ms
# Speed: 3.9ms preprocess, 84.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.7ms
# Speed: 3.7ms preprocess, 105.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 4.0ms preprocess, 113.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.1ms
# Speed: 4.0ms preprocess, 109.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.6ms
# Speed: 4.0ms preprocess, 107.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 3.7ms preprocess, 105.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.0ms
# Speed: 4.0ms preprocess, 105.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.0ms
# Speed: 4.1ms preprocess, 113.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 110.0ms
# Speed: 4.1ms preprocess, 110.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.3ms
# Speed: 4.8ms preprocess, 97.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.1ms
# Speed: 4.0ms preprocess, 114.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.4ms
# Speed: 4.1ms preprocess, 102.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.8ms
# Speed: 3.8ms preprocess, 84.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.4ms
# Speed: 3.8ms preprocess, 119.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.2ms
# Speed: 4.7ms preprocess, 85.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.9ms
# Speed: 3.5ms preprocess, 99.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.8ms
# Speed: 3.9ms preprocess, 86.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.3ms
# Speed: 3.7ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.7ms
# Speed: 3.9ms preprocess, 77.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.4ms
# Speed: 4.1ms preprocess, 83.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.3ms
# Speed: 4.4ms preprocess, 69.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 4.0ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.0ms
# Speed: 4.1ms preprocess, 87.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.1ms
# Speed: 4.1ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.1ms
# Speed: 3.7ms preprocess, 80.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.9ms
# Speed: 3.9ms preprocess, 106.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.7ms
# Speed: 3.8ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.2ms
# Speed: 3.7ms preprocess, 115.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.5ms
# Speed: 4.0ms preprocess, 101.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.1ms
# Speed: 4.0ms preprocess, 128.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.0ms
# Speed: 3.7ms preprocess, 92.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.0ms
# Speed: 4.3ms preprocess, 92.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.0ms
# Speed: 4.3ms preprocess, 98.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.8ms
# Speed: 4.4ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 4.6ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.3ms
# Speed: 3.8ms preprocess, 101.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.3ms
# Speed: 4.4ms preprocess, 85.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.2ms
# Speed: 3.8ms preprocess, 89.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.4ms
# Speed: 3.6ms preprocess, 92.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.5ms
# Speed: 4.2ms preprocess, 102.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.1ms
# Speed: 4.1ms preprocess, 96.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.0ms
# Speed: 4.1ms preprocess, 91.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.8ms
# Speed: 3.9ms preprocess, 87.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.1ms
# Speed: 4.0ms preprocess, 79.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.8ms
# Speed: 4.0ms preprocess, 74.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.0ms
# Speed: 3.7ms preprocess, 66.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.6ms
# Speed: 3.9ms preprocess, 83.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.3ms
# Speed: 4.0ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.8ms
# Speed: 4.1ms preprocess, 79.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.4ms
# Speed: 3.9ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 4.7ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.0ms
# Speed: 4.1ms preprocess, 70.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.4ms
# Speed: 3.9ms preprocess, 82.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.4ms
# Speed: 4.1ms preprocess, 77.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 4.8ms preprocess, 85.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.2ms
# Speed: 3.8ms preprocess, 89.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.4ms
# Speed: 3.9ms preprocess, 78.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.9ms
# Speed: 3.9ms preprocess, 84.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.4ms
# Speed: 4.0ms preprocess, 76.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.9ms
# Speed: 11.3ms preprocess, 82.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.3ms
# Speed: 3.8ms preprocess, 90.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.0ms
# Speed: 3.7ms preprocess, 91.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.4ms
# Speed: 4.0ms preprocess, 89.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.6ms
# Speed: 4.3ms preprocess, 85.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.9ms
# Speed: 3.7ms preprocess, 92.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 3.7ms preprocess, 88.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("../models/yantra_model_1.pt")

# Load video file
url = "../test_videos/static_prob_1_org.mp4"
cap = cv2.VideoCapture(url)

# Initialize counters and tracking
left_counter = 0
right_counter = 0
straight_counter = 0
previous_centers = {}
counted_objects = {'left': set(), 'right': set(), 'straight': set()}

def check_line_crossing(p1, p2, line_start, line_end):
    """Check if a point has crossed a line"""
    # Check if the center point crosses the line from top to bottom
    line_y1 = line_start[1]
    line_y2 = line_end[1]
    center_y1 = p1[1]
    center_y2 = p2[1]

    # Check if the center has moved from above the line to below the line
    if (center_y1 > line_y1 and center_y2 < line_y2) or (center_y1 < line_y1 and center_y2 > line_y2):
        return True
    return False

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    results = model(frame)
    current_centers = {}
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])
            
            # Calculate center point
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            object_id = f"{cls}_{x1}_{y1}_{x2}_{y2}"
            current_centers[object_id] = (center_x, center_y)
            
            # Draw the bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"{model.names[cls]} {conf:.2f}"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Draw the center dot at the center of the bounding box
            cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)  # Red dot with radius 5
            
            # Check for line crossings if we have previous position
            if object_id in previous_centers:
                prev_center = previous_centers[object_id]
                curr_center = (center_x, center_y)
                
                # Check left line crossing
                if (object_id not in counted_objects['left'] and 
                    check_line_crossing(prev_center, curr_center, (218, 1584), (451, 940))):
                    left_counter += 1
                    counted_objects['left'].add(object_id)
                
                # Check right line crossing
                if (object_id not in counted_objects['right'] and 
                    check_line_crossing(prev_center, curr_center, (2093, 1510), (1604, 844))):
                    right_counter += 1
                    counted_objects['right'].add(object_id)
                
                # Check straight line crossing
                if (object_id not in counted_objects['straight'] and 
                    check_line_crossing(prev_center, curr_center, (2093, 1510), (218, 1584))):
                    straight_counter += 1
                    counted_objects['straight'].add(object_id)

    # Draw the lines (keeping your original visualization)
    cv2.line(frame, (218, 1584), (451, 940), (0, 255, 0), 3)
    cv2.line(frame, (2093, 1510), (1604, 844), (0, 255, 0), 3)
    cv2.line(frame, (2093, 1510), (218, 1584), (0, 255, 0), 3)
    
    # Display counters
    cv2.putText(frame, f"Left: {left_counter}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Right: {right_counter}", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Straight: {straight_counter}", (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Update previous centers
    previous_centers = current_centers.copy()
    
    cv2.imshow("ESP32-CAM", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 cars, 62.9ms
# Speed: 4.3ms preprocess, 62.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 58.4ms
# Speed: 1.6ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.2ms
# Speed: 1.7ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 78.9ms
# Speed: 1.9ms preprocess, 78.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.8ms
# Speed: 2.3ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# 2025-02-08 11:58:44.606 python[88100:2508091] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-08 11:58:44.606 python[88100:2508091] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 480x640 4 cars, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.0ms
# Speed: 1.8ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.5ms
# Speed: 1.6ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.2ms
# Speed: 2.4ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 48.0ms
# Speed: 1.7ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.6ms
# Speed: 1.7ms preprocess, 39.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.3ms
# Speed: 1.7ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.3ms
# Speed: 2.4ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.8ms
# Speed: 1.5ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.1ms
# Speed: 1.5ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.1ms
# Speed: 1.5ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.7ms
# Speed: 1.9ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.6ms
# Speed: 1.7ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 52.0ms
# Speed: 1.6ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 48.6ms
# Speed: 1.9ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 67.9ms
# Speed: 1.6ms preprocess, 67.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.7ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.5ms
# Speed: 2.0ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.2ms
# Speed: 1.5ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 47.0ms
# Speed: 1.6ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.1ms
# Speed: 1.8ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.4ms
# Speed: 4.2ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.6ms
# Speed: 1.6ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.7ms
# Speed: 1.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 36.8ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 47.9ms
# Speed: 1.8ms preprocess, 47.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.7ms
# Speed: 1.9ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 45.5ms
# Speed: 1.6ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 49.9ms
# Speed: 5.8ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 37.2ms
# Speed: 1.6ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.5ms
# Speed: 1.9ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.5ms
# Speed: 1.7ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.2ms
# Speed: 1.8ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.2ms
# Speed: 1.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.8ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 49.1ms
# Speed: 1.6ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.5ms
# Speed: 1.9ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.3ms
# Speed: 2.1ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.4ms
# Speed: 1.8ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 44.5ms
# Speed: 2.0ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.4ms
# Speed: 1.7ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.7ms
# Speed: 5.0ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.6ms
# Speed: 1.6ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.4ms
# Speed: 1.5ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.8ms
# Speed: 1.7ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 60.4ms
# Speed: 2.1ms preprocess, 60.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 48.6ms
# Speed: 1.7ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.8ms
# Speed: 1.9ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 52.7ms
# Speed: 1.7ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 70.8ms
# Speed: 1.7ms preprocess, 70.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.4ms
# Speed: 1.7ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.4ms
# Speed: 1.5ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.9ms
# Speed: 1.7ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.5ms
# Speed: 1.7ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 46.2ms
# Speed: 1.6ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 39.4ms
# Speed: 1.5ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 38.2ms
# Speed: 1.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 41.9ms
# Speed: 1.9ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 46.7ms
# Speed: 1.8ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 49.2ms
# Speed: 1.7ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 44.0ms
# Speed: 1.6ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.9ms
# Speed: 1.6ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.6ms
# Speed: 1.6ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.9ms
# Speed: 1.7ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.7ms
# Speed: 1.7ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.6ms
# Speed: 1.8ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.3ms
# Speed: 1.8ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.6ms
# Speed: 1.8ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.3ms
# Speed: 1.9ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.2ms
# Speed: 2.8ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.5ms
# Speed: 1.8ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.6ms
# Speed: 1.7ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 54.6ms
# Speed: 1.6ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 51.9ms
# Speed: 2.2ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.9ms
# Speed: 1.8ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.3ms
# Speed: 1.7ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.4ms
# Speed: 1.6ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.8ms
# Speed: 1.7ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 49.3ms
# Speed: 1.6ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.4ms
# Speed: 1.6ms preprocess, 84.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.2ms
# Speed: 1.6ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.5ms
# Speed: 2.3ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.8ms
# Speed: 1.9ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 48.2ms
# Speed: 1.8ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 46.6ms
# Speed: 1.8ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.4ms
# Speed: 1.6ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 41.4ms
# Speed: 1.6ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.5ms
# Speed: 1.9ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.2ms
# Speed: 1.9ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 50.6ms
# Speed: 4.2ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 45.9ms
# Speed: 1.6ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vip, 43.8ms
# Speed: 1.5ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("../models/yantra_model_1.pt")

# Load video file
url = "../test_videos/static_prob_1_org.mp4"
cap = cv2.VideoCapture(url)

# Initialize counters and tracking
left_counter = 0
right_counter = 0
straight_counter = 0
previous_centers = {}
counted_objects = {'left': set(), 'right': set(), 'straight': set()}

def check_line_crossing(p1, p2, line_start, line_end):
    """Check if a point has crossed a line"""
    # Check if the center point crosses the line from top to bottom
    line_y1 = line_start[1]
    line_y2 = line_end[1]
    center_y1 = p1[1]
    center_y2 = p2[1]

    # Check if the center has moved from above the line to below the line
    if (center_y1 > line_y1 and center_y2 < line_y2) or (center_y1 < line_y1 and center_y2 > line_y2):
        return True
    return False

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    results = model(frame)
    current_centers = {}
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])
            
            # Calculate center point
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            object_id = f"{cls}_{x1}_{y1}_{x2}_{y2}"
            current_centers[object_id] = (center_x, center_y)
            
            # Draw the bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"{model.names[cls]} {conf:.2f}"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Draw the center dot at the center of the bounding box
            cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)  # Red dot with radius 5
            
            # Check for line crossings if we have previous position
            if object_id in previous_centers:
                prev_center = previous_centers[object_id]
                curr_center = (center_x, center_y)
                
                # Check left line crossing
                if (object_id not in counted_objects['left'] and 
                    check_line_crossing(prev_center, curr_center, (218, 1584), (451, 940))):
                    left_counter += 1
                    counted_objects['left'].add(object_id)
                
                # Check right line crossing
                if (object_id not in counted_objects['right'] and 
                    check_line_crossing(prev_center, curr_center, (2093, 1510), (1604, 844))):
                    right_counter += 1
                    counted_objects['right'].add(object_id)
                
                # Check straight line crossing
                if (object_id not in counted_objects['straight'] and 
                    check_line_crossing(prev_center, curr_center, (2093, 1510), (218, 1584))):
                    straight_counter += 1
                    counted_objects['straight'].add(object_id)

    # Draw the lines (keeping your original visualization)
    cv2.line(frame, (218, 1584), (451, 940), (0, 255, 0), 3)
    cv2.line(frame, (2093, 1510), (1604, 844), (0, 255, 0), 3)
    cv2.line(frame, (2093, 1510), (218, 1584), (0, 255, 0), 3)
    
    # Display counters
    cv2.putText(frame, f"Left: {left_counter}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Right: {right_counter}", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Straight: {straight_counter}", (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Update previous centers
    previous_centers = current_centers.copy()
    
    cv2.imshow("ESP32-CAM", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Callback function to display coordinates
def show_coordinates(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:  # Detect mouse movement
        print(f"X: {x}, Y: {y}")  # Print coordinates

# Open video stream
cap = cv2.VideoCapture("http://172.18.239.30:8080/video")

# Create window and set fullscreen
cv2.namedWindow("Video with Line", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Video with Line", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

# Set mouse callback to track coordinates
cv2.setMouseCallback("Video with Line", show_coordinates)

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video")
        break

    # Show the video in the window
    cv2.imshow("Video with Line", frame)

    # Exit the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-02-08 22:35:59.687 python[4483:2846989] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-08 22:35:59.687 python[4483:2846989] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# X: 793, Y: 841
# X: 847, Y: 800
# X: 926, Y: 757
# X: 1050, Y: 716
# X: 1090, Y: 704
# X: 1114, Y: 696
# X: 1139, Y: 689
# X: 1166, Y: 684
# X: 1170, Y: 683
# X: 1171, Y: 683
# X: 1172, Y: 682
# X: 1172, Y: 682
# X: 1172, Y: 681
# X: 1172, Y: 674
# X: 1158, Y: 598
# X: 1158, Y: 598
# X: 1159, Y: 598
# X: 1210, Y: 624
# X: 1263, Y: 641
# X: 1298, Y: 650
# X: 1318, Y: 663
# X: 1333, Y: 679
# X: 1348, Y: 694
# X: 1370, Y: 707
# X: 1391, Y: 714
# X: 1422, Y: 730
# X: 1461, Y: 753
# X: 1479, Y: 760
# X: 1515, Y: 774
# X: 1544, Y: 784
# X: 1574, Y: 795
# X: 1603, Y: 819
# X: 1630, Y: 850
# X: 1645, Y: 867
# X: 1657, Y: 881
# X: 1660, Y: 888
# X: 1662, Y: 903
# X: 1662, Y: 910
# X: 1662, Y: 914
# X: 1662, Y: 915
# X: 1666, Y: 919
# X: 1677, Y: 931
# X: 1679, Y: 934
# X: 1680, Y: 941
# X: 1680, Y: 946
# X: 1680, Y: 953
# X: 1679, Y: 954
# X: 1679, Y: 954
# X: 1679, Y: 954
# X: 1679, Y: 962
# X: 1679, Y: 971
# X: 1679, Y: 978
# X: 1679, Y: 980
# X: 1679, Y: 981
# X: 1680, Y: 981
# X: 1681, Y: 981
# X: 1683, Y: 982
# X: 1684, Y: 982
# X: 1684, Y: 982
# X: 1684, Y: 983
# X: 1684, Y: 983
# X: 1684, Y: 982
# X: 1684, Y: 981
# X: 1686, Y: 977
# X: 1686, Y: 976
# X: 1686, Y: 986
# X: 1688, Y: 992
# X: 1695, Y: 996
# X: 1701, Y: 999
# X: 1707, Y: 999
# X: 1717, Y: 999
# X: 1733, Y: 999
# X: 1735, Y: 999
# X: 1734, Y: 999
# X: 1709, Y: 1001
# X: 1707, Y: 1001
# X: 1707, Y: 1001
# X: 1707, Y: 1001
# X: 1707, Y: 1003
# X: 1707, Y: 1003
# X: 1708, Y: 1003
# X: 1708, Y: 1003
# X: 1708, Y: 1003
# X: 1709, Y: 1003
# X: 1709, Y: 1003
# X: 1710, Y: 1003
# X: 1710, Y: 1003
# X: 1710, Y: 1003
# X: 1710, Y: 1003
# X: 1711, Y: 1003
# X: 1713, Y: 1003
# X: 1714, Y: 1003
# X: 1715, Y: 1003
# X: 1715, Y: 1003
# X: 1716, Y: 1003
# X: 1717, Y: 1003
# X: 1717, Y: 1003
# X: 1717, Y: 1003
# X: 1715, Y: 1003
# X: 1715, Y: 1003
# X: 1715, Y: 1003
# X: 1714, Y: 1003
# X: 1713, Y: 1003
# X: 932, Y: 759
# X: 1494, Y: 355
# X: 1510, Y: 341
# X: 1519, Y: 320
# X: 1523, Y: 297
# X: 1529, Y: 277
# X: 1546, Y: 256
# X: 1568, Y: 242
# X: 1590, Y: 234
# X: 1611, Y: 230
# X: 1626, Y: 228
# X: 1627, Y: 228
# X: 1627, Y: 235
# X: 1628, Y: 243
# X: 1629, Y: 244
# X: 1629, Y: 245
# X: 1625, Y: 246
# X: 1614, Y: 248
# X: 1608, Y: 248
# X: 1608, Y: 248
# X: 1602, Y: 246
# X: 1594, Y: 241
# X: 1586, Y: 234
# X: 1582, Y: 231
# X: 1581, Y: 229
# X: 1581, Y: 229
# X: 1581, Y: 229
# X: 1581, Y: 228
# X: 1581, Y: 228
# X: 1581, Y: 228
# X: 1578, Y: 228
# X: 1576, Y: 227
# X: 1575, Y: 227
# X: 1575, Y: 227
# X: 1575, Y: 227
# X: 1574, Y: 227
# X: 1572, Y: 227
# X: 1562, Y: 227
# X: 1559, Y: 227
# X: 1558, Y: 227
# X: 1558, Y: 226
# X: 877, Y: 446
# End of video
# [http @ 0x600002ccc080] Stream ends prematurely at 351325896, should be 18446744073709551615

# %%
X: 495, Y: 164 X: 327, Y: 970

# %%
X: 1689, Y: 979 X: 203, Y: 913

# %%
X: 1713, Y: 1003 X: 1558, Y: 227
